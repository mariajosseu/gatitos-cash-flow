# %%
from main import read_expenses_files, process_expenses
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = read_expenses_files()
df_processed = process_expenses(df)

# %%
df_processed.Detalle.value_counts()
# Out:
# Detalle
# Rejsekort           153
# Netto                65
# Coop365              35
# Foetex               21
# UNIQLO               14
#                    ...
# Mad Kaffe Lyngby      1
# Baum Und Pferdg       1
# Loomisp               1
# Buka                  1
# De Fire Arstide       1
# Name: count, Length: 148, dtype: int64

# %%
def plot_expenses(df, Basico = True):
    if Basico:
        # Filtrar solo gastos básicos
        df = df[df["Gasto Básico"] == True]
        # Group by category and sum amounts
        category_sums = df.groupby(['Año', 'Mes', 'Categoría'])['Monto Neto'].sum(numeric_only=True)
        
        # Convert to dataframe for plotly
        df_plot = category_sums.reset_index()
    else:
        # Group by category and sum amounts
        category_sums = df.groupby(['Año', 'Mes', 'Categoría'])['Monto Neto'].sum(numeric_only=True)
        # Convert to dataframe for plotly
        df_plot = category_sums.reset_index()

    fig = px.bar(
        df_plot,
        x='Mes',
        y='Monto Neto',
        color='Categoría',
        barmode='stack',
        facet_col='Año',
        labels={'Monto Neto': 'Monto Neto', 'Mes': 'Mes', 'Categoría': 'Categoría'}
    )

    # Calcular el total por mes y año
    total_mes = df_plot.groupby(['Año', 'Mes'])['Monto Neto'].sum().reset_index()

    # Agregar solo el número en millones como texto
    for año in total_mes['Año'].unique():
        datos_año = total_mes[total_mes['Año'] == año]
        fig.add_scatter(
            x=datos_año['Mes'],
            y=datos_año['Monto Neto'],
            mode='text',
            text=(datos_año['Monto Neto'] / 1_000_000).round(2).astype(str) + 'M',
            textposition='top center',
            name=f'Total {año}',
            showlegend=False,
            row=1, col=list(total_mes['Año'].unique()).index(año) + 1
        )
    fig.show()

# %%
plot_expenses(df_processed)

# %%
df_processed[df_processed["Gasto Básico"]]["Categoría"].value_counts()
# Out:
# Categoría
# Comida        220
# Transporte    168
# Telefonía      15
# Arriendo        7
# Name: count, dtype: int64

# %%
plot_expenses(df_processed, Basico=False)

# %%
df_processed[df_processed["Categoría"] == "Ropa"]
# Out:
#         Fecha           Detalle Categoría   Tipo Pagado por  Monto USD  \
# 2  2025-09-01      Friluftsland      Ropa  Willy      Willy     157.44
# 3  2025-09-02               HyM      Ropa  Willy      Willy      76.89
# 4  2025-09-02  Neye Laedervarer      Ropa  Willy      Willy      47.02
# 6  2025-09-02               HyM      Ropa  Willy      Willy      63.53
# 19 2025-09-08             Boozt      Ropa  Willy      Willy      39.17
# 20 2025-09-08             Boozt      Ropa   Cote      Willy      13.99
# 43 2025-09-15      Friluftsland      Ropa  Willy      Willy     150.95
# 50 2025-09-15      Flying Tiger      Ropa   Cote       Cote        NaN
# 52 2025-09-15            UNIQLO      Ropa   Cote       Cote        NaN
# 88 2025-09-27            UNIQLO      Ropa   Cote       Cote        NaN
# 5  2025-08-05            UNIQLO      Ropa  Willy      Willy      30.95
# 6  2025-08-05            UNIQLO      Ropa  Willy      Willy     108.71
# 15 2025-08-05            UNIQLO      Ropa   Cote       Cote        NaN
# 24 2025-08-06             Naked      Ropa   Cote       Cote        NaN
# 34 2025-08-08            UNIQLO      Ropa  Willy      Willy     172.31
# 41 2025-08-08            UNIQLO      Ropa   Cote       Cote        NaN
# 53 2025-08-10             Illum      Ropa  Willy      Willy      44.93
# 57 2025-08-10             Illum      Ropa   Cote       Cote        NaN
# 73 2025-08-13   Baum Und Pferdg      Ropa   Cote       Cote        NaN
# 9  2025-11-02           Magasin      Ropa  Willy      Willy      30.39
# 32 2025-11-08            UNIQLO      Ropa  Willy      Willy     131.50
# 55 2025-11-16            UNIQLO      Ropa   Cote      Willy      30.06
# 56 2025-11-16            UNIQLO      Ropa  Willy      Willy      87.77
# 91 2025-11-22            UNIQLO      Ropa   Cote       Cote        NaN
# 11 2025-10-05           Magasin      Ropa  Willy      Willy      29.77
# 13 2025-10-05             Matas      Ropa  Willy      Willy      23.62
# 17 2025-10-05           Magasin      Ropa   Cote       Cote        NaN
# 26 2025-10-10      Friluftsland      Ropa  Willy      Willy      93.47
# 29 2025-10-11        Dr Martens      Ropa  Willy      Willy      15.58
# 34 2025-10-13       Norr Retail      Ropa  Willy      Willy      11.68
# 40 2025-10-18             Boozt      Ropa  Willy      Willy     190.81
# 42 2025-10-25      Friluftsland      Ropa  Willy      Willy     479.96
# 29 2026-01-05           Sport24      Ropa  Willy      Willy      29.77
# 50 2026-01-10            UNIQLO      Ropa  Willy      Willy      41.68
# 98 2026-01-25            UNIQLO      Ropa  Willy      Willy     115.43
#
#     Monto CLP  Monto Neto  Año-Mes   Año  Mes  Gasto Básico
# 2         NaN  153850.368  2025-09  2025    9         False
# 3         NaN   75136.908  2025-09  2025    9         False
# 4         NaN   45947.944  2025-09  2025    9         False
# 6         NaN   62081.516  2025-09  2025    9         False
# 19        NaN   38276.924  2025-09  2025    9         False
# 20        NaN   13671.028  2025-09  2025    9         False
# 43        NaN  147508.340  2025-09  2025    9         False
# 50     9226.0    9226.000  2025-09  2025    9         False
# 52    54171.0   54171.000  2025-09  2025    9         False
# 88    77033.0   77033.000  2025-09  2025    9         False
# 5         NaN   30454.800  2025-08  2025    8         False
# 6         NaN  106970.640  2025-08  2025    8         False
# 15    61898.0   61898.000  2025-08  2025    8         False
# 24   225313.0  225313.000  2025-08  2025    8         False
# 34        NaN  169553.040  2025-08  2025    8         False
# 41    70352.0   70352.000  2025-08  2025    8         False
# 53        NaN   44211.120  2025-08  2025    8         False
# 57    43278.0   43278.000  2025-08  2025    8         False
# 73   206027.0  206027.000  2025-08  2025    8         False
# 9         NaN   28505.820  2025-11  2025   11         False
# 32        NaN  123347.000  2025-11  2025   11         False
# 55        NaN   28196.280  2025-11  2025   11         False
# 56        NaN   82328.260  2025-11  2025   11         False
# 91   171362.0  171362.000  2025-11  2025   11         False
# 11        NaN   28341.040  2025-10  2025   10         False
# 13        NaN   22486.240  2025-10  2025   10         False
# 17    24868.0   24868.000  2025-10  2025   10         False
# 26        NaN   88983.440  2025-10  2025   10         False
# 29        NaN   14832.160  2025-10  2025   10         False
# 34        NaN   11119.360  2025-10  2025   10         False
# 40        NaN  181651.120  2025-10  2025   10         False
# 42        NaN  456921.920  2025-10  2025   10         False
# 29        NaN   26405.990  2026-01  2026    1         False
# 50        NaN   36970.160  2026-01  2026    1         False
# 98        NaN  102386.410  2026-01  2026    1         False

# %%
def plot_transportes(df):
    # Filtrar solo gastos en la categoría "Transporte"
    df = df[(df["Categoría"] == "Transporte") & (df["Tipo"] == "Cote")]

    category_sums = df.groupby(['Año', 'Mes', 'Detalle'])['Monto Neto'].sum(numeric_only=True)
    # Convert to dataframe for plotly
    df_plot = category_sums.reset_index()

    fig = px.bar(
        df_plot,
        x='Mes',
        y='Monto Neto',
        color='Detalle',
        barmode='stack',
        facet_col='Año',
        labels={'Monto Neto': 'Monto Neto', 'Mes': 'Mes', 'Detalle': 'Detalle'}
    )

    # Calcular el total por mes y año
    total_mes = df_plot.groupby(['Año', 'Mes'])['Monto Neto'].sum().reset_index()

    # Agregar solo el número en millones como texto
    for año in total_mes['Año'].unique():
        datos_año = total_mes[total_mes['Año'] == año]
        fig.add_scatter(
            x=datos_año['Mes'],
            y=datos_año['Monto Neto'],
            mode='text',
            text=(datos_año['Monto Neto'] / 1_000_000).round(2).astype(str) + 'M',
            textposition='top center',
            name=f'Total {año}',
            showlegend=False,
            row=1, col=list(total_mes['Año'].unique()).index(año) + 1
        )
    fig.show()

# %%
plot_transportes(df_processed)
